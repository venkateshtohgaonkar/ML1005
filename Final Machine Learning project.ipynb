# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Here we are imported some basic libraries

# %%
df = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\Excel File\telcoo.csv")

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Under 30 Senior Citizen Married Dependents  \
# 0  8779-QRDMV    Male   78       No            Yes      No         No
# 1  7495-OOKFY  Female   74       No            Yes     Yes        Yes
# 2  1658-BYGOY    Male   71       No            Yes      No        Yes
# 3  4598-XLKNJ  Female   78       No            Yes     Yes        Yes
# 4  4846-WHAFZ  Female   80       No            Yes     Yes        Yes
#
#    Number of Dependents        Country       State  ... Total Charges  \
# 0                     0  United States  California  ...         39.65
# 1                     1  United States  California  ...        633.30
# 2                     3  United States  California  ...       1752.55
# 3                     1  United States  California  ...       2514.50
# 4                     1  United States  California  ...       2868.15
#
#    Total Refunds  Total Extra Data Charges  Total Long Distance Charges  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 48 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Under 30                           7043 non-null   object
#  4   Senior Citizen                     7043 non-null   object
#  5   Married                            7043 non-null   object
#  6   Dependents                         7043 non-null   object
#  7   Number of Dependents               7043 non-null   int64
#  8   Country                            7043 non-null   object
#  9   State                              7043 non-null   object
#  10  City                               7043 non-null   object
# ...

# %%
#here we have  successfully uploaded our data

# %% [markdown]
# Churn Label is our target column and remaining 46 is our input column and 7043 rows

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Under 30                                0
# Senior Citizen                          0
# Married                                 0
# Dependents                              0
# Number of Dependents                    0
# Country                                 0
# State                                   0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Population                              0
# Quarter                                 0
# Referred a Friend                       0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# ...

# %%
df.dropna(inplace = True)

# %% [markdown]
# after removing the null value our rows decreases to 2493

# %% [raw]
# CustomerID: A unique ID that identifies ech customer.
# Gender: The customer’s gender: Male, Femal
# Age: The customer’s current age, in years, at the tie the fiscal quarter ended.
# Senior Citizen: Indicates if the customer is 65 or oler: Yes, No
# Married: Indicates if the customer is married: Yes, No
# Dependents: Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
# Number of Dependents: Indicates the number of dependents that live with the customer.
# CustomerID: A unique ID that identifies each customer.
# Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
# Country: The country of the customer’s primary residence.
# State: The state of the customer’s primary residence.
# City: The city of the customer’s primary residence.
# Zip Code: The zip code of the customer’s primary residence.
# Latitude: The latitude of the customer’s primary residence.
# Longitude: The longitude of the customer’s primary residence.
# Zip Code: The zip code of the customer’s primary residence.
# Population: A current population estimate for the entire Zip Code area.
# CustomerID: A unique ID that identifies each customer.
# Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
# Quarter: The fiscal quarter that the data has been derived from (e.g. Q3).
# Referred a Friend: Indicates if the customer has ever referred a friend or family member to this company: Yes, No
# Number of Referrals: Indicates the number of referrals to date that the customer has made.
# Tenure in Months: Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
# Offer: Identifies the last marketing offer that the customer accepted, if applicable. Values include None, Offer A, Offer B, Offer C, Offer D, and Offer E.
# Phone Service: Indicates if the customer subscribes to home phone service with the company: Yes, No
# Avg Monthly Long Distance Charges: Indicates the customer’s average long distance charges, calculated to the end of the quarter specified above.
# Multiple Lines: Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
# Internet Service: Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
# Avg Monthly GB Download: Indicates the customer’s average download volume in gigabytes, calculated to the end of the quarter specified above.
# Online Security: Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
# Online Backup: Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
# Device Protection Plan: Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
# Premium Tech Support: Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
# Streaming TV: Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. The company does not charge an additional fee for this service.
# Streaming Movies: Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
# Streaming Music: Indicates if the customer uses their Internet service to stream music from a third party provider: Yes, No. The company does not charge an additional fee for this service.
# Unlimited Data: Indicates if the customer has paid an additional monthly fee to have unlimited data downloads/uploads: Yes, No
# Contract: Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
# Paperless Billing: Indicates if the customer has chosen paperless billing: Yes, No
# Payment Method: Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
# Monthly Charge: Indicates the customer’s current total monthly charge for all their services from the company.
# Total Charges: Indicates the customer’s total charges, calculated to the end of the quarter specified above.
# Total Refunds: Indicates the customer’s total refunds, calculated to the end of the quarter specified above.
# Total Extra Data Charges: Indicates the customer’s total charges for extra data downloads above those specified in their plan, by the end of the quarter specified above.
# Total Long Distance Charges: Indicates the customer’s total charges for long distance above those specified in their plan, by the end of the quarter specified above.
# CustomerID: A unique ID that identifies each customer.
# Count: A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
# Quarter: The fiscal quarter that the data has been derived from (e.g. Q3).
# Satisfaction Score: A customer’s overall satisfaction rating of the company from 1 (Very Unsatisfied) to 5 (Very Satisfied).
# Satisfaction Score Label: Indicates the text version of the score (1-5) as a text string.
# Customer Status: Indicates the status of the customer at the end of the quarter: Churned, Stayed, or Joined
# Churn Label: Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
# Churn Value: 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
# Churn Score: A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
# Churn Score Category: A calculation that assigns a Churn Score to one of the following categories: 0-10, 11-20, 21-30, 31-40, 41-50, 51-60, 61-70, 71-80, 81-90, and 91-100
# CLTV: Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
# CLTV Category: A calculation that assigns a CLTV value to one of the following categories: 2000-2500, 2501-3000, 3001-3500, 3501-4000, 4001-4500, 4501-5000, 5001-5500, 5501-6000, 6001-6500, and 6501-7000.

# %%
df.describe().T
# Out:
#                                     count          mean           std  \
# Age                                2493.0     46.707982     17.093612
# Number of Dependents               2493.0      0.406338      0.921341
# Zip Code                           2493.0  93444.219013   1835.121516
# Latitude                           2493.0     36.120280      2.459472
# Longitude                          2493.0   -119.664276      2.125717
# Population                         2493.0  21896.282792  21113.024018
# Number of Referrals                2493.0      1.985560      3.019830
# Tenure in Months                   2493.0     34.038508     25.240928
# Avg Monthly Long Distance Charges  2493.0     22.613329     15.858970
# Avg Monthly GB Download            2493.0     26.738869     19.828549
# Monthly Charge                     2493.0     77.175531     22.146812
# Total Charges                      2493.0   2844.533373   2425.195980
# ...

# %%
df["Churn Label"].value_counts()
# Out:
# Churn Label
# No     1736
# Yes     757
# Name: count, dtype: int64

# %% [markdown]
# here we need to resample the data for that first we need to do encoding

# %% [markdown]
#  # Data visualization

# %%
pd.crosstab(df["Churn Label"],df["Gender"])
# Out:
# Gender       Female  Male
# Churn Label
# No              853   883
# Yes             363   394

# %%
pd.crosstab(df["Churn Label"],df["Gender"]).plot.pie(title = "Chrun label vs Gender",subplots = True,legend = False,autopct = "%.2f%%")
# Out:
# array([<Axes: ylabel='Female'>, <Axes: ylabel='Male'>], dtype=object)

# %% [markdown]
# from the above pie chart we get to know that 70.1% women still remain in the company and 69.1% Male still remain

# %%
df.groupby("Churn Label")["Age"].mean()
# Out:
# Churn Label
# No     45.561636
# Yes    49.336856
# Name: Age, dtype: float64

# %% [markdown]
# the average age of people stayed in company is 45.5 and leaving the company is approx 50

# %%
df.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    47.038651
# Male      46.393109
# Name: Age, dtype: float64

# %% [markdown]
# the average of age of female in the company is 47 and for male is 46.3

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      1277
# Female    1216
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df["Gender"],hue=df["Churn Label"])
plt.title("Count of Gender in chrun label")
plt.xlabel("gender")
plt.show()

# %%
pd.crosstab(df["Churn Label"],df["Dependents"])
# Out:
# Dependents     No  Yes
# Churn Label
# No           1273  463
# Yes           724   33

# %% [markdown]
# It appears that among the employees who are not dependent on others, a larger proportion leave the company compared to those who are dependent. Specifically, there are only 33 instances where individuals who are dependent on others leave the company, whereas a significantly higher number, 724 individuals, leave the company when they are not dependent on anyone else.

# %%
pd.crosstab(df["Churn Label"],df["Number of Dependents"])
# Out:
# Number of Dependents     0    1    2    3  4  5  6  8  9
# Churn Label
# No                    1273  151  161  142  3  3  1  1  1
# Yes                    724   13   10    9  1  0  0  0  0

# %% [markdown]
# We can conclude that the number of individuals with zero dependents is higher in both churn labels. Specifically, there are 1,273 instances where individuals with zero dependents have not churned, and 724 instances where individuals with zero dependents have churned.

# %%
pd.crosstab(df["Churn Label"],df["Married"])
# Out:
# Married       No  Yes
# Churn Label
# No           775  961
# Yes          487  270

# %%
pd.crosstab(df["Churn Label"],df["Married"]).plot.pie(title = "Chrun label vs Married",subplots = True,legend = False,autopct = "%.2f%%")
# Out:
# array([<Axes: ylabel='No'>, <Axes: ylabel='Yes'>], dtype=object)

# %% [markdown]
# After marriage, approximately 21.9% of employees leave the company, while the likelihood of leaving the company is notably higher among unmarried individuals, at 78.07%.

# %%
pd.crosstab(df["Churn Label"],df["Under 30"])
# Out:
# Under 30       No  Yes
# Churn Label
# No           1373  363
# Yes           618  139

# %%
pd.crosstab(df["Churn Label"],df["Under 30"]).plot.pie(title = "Chrun label vs under 30",subplots = True,legend = False,autopct = "%.2f%%")
# Out:
# array([<Axes: ylabel='No'>, <Axes: ylabel='Yes'>], dtype=object)

# %% [markdown]
# Among individuals who are not under 30, a significant proportion, specifically 1,373 individuals, or 68.9%, remain with the company. Conversely, individuals aged 30 and above are more inclined to leave the company, accounting for 27.9% of departures.

# %%
pd.crosstab(df["Churn Label"],df["Senior Citizen"])
# Out:
# Senior Citizen    No  Yes
# Churn Label
# No              1484  252
# Yes              574  183

# %%
pd.crosstab(df["Churn Label"],df["Senior Citizen"]).plot.pie(title = "Chrun label vs senior Citizen",subplots = True,legend = False,autopct = "%.2f%%")
# Out:
# array([<Axes: ylabel='No'>, <Axes: ylabel='Yes'>], dtype=object)

# %% [markdown]
# Among senior citizens, a minority, comprising 183 individuals or 42.07%, opt to leave the company, while the majority, constituting 57.93%, remain with the company. Conversely, non-senior citizens display a higher propensity to stay, with 72.11% remaining in the company, while 27.98% choose to depart.

# %%
df["State"].value_counts()
# Out:
# State
# California    2493
# Name: count, dtype: int64

# %%
df["City"].value_counts()
# Out:
# City
# San Diego         103
# Los Angeles        96
# San Jose           47
# Sacramento         32
# San Francisco      29
#                  ...
# Catheys Valley      1
# Philo               1
# Dulzura             1
# Diamond Bar         1
# La Quinta           1
# Name: count, Length: 939, dtype: int64

# %%
df["Country"].value_counts()
# Out:
# Country
# United States    2493
# Name: count, dtype: int64

# %% [markdown]
# In the United States, California boasts a total of 939 cities. Among these cities, San Diego stands out with a higher concentration of customers, totaling 103 individuals.

# %%
highest_population_city = df.groupby("City")["Population"].mean().idxmax()
highest_population_city
# Out:
# 'Bell'

# %%
df.groupby("Gender")["Population"].sum()
# Out:
# Gender
# Female    26803255
# Male      27784178
# Name: Population, dtype: int64

# %% [markdown]
# Male Population is more as compare to the Female

# %%
df[df["Churn Label"] =="Yes"].groupby("Gender")["Population"].sum()
# Out:
# Gender
# Female    8814908
# Male      9116045
# Name: Population, dtype: int64

# %%
df[df["Churn Label"] =="No"].groupby("Gender")["Population"].sum()
# Out:
# Gender
# Female    17988347
# Male      18668133
# Name: Population, dtype: int64

# %%
df["Quarter"].value_counts()
# Out:
# Quarter
# Q3    2493
# Name: count, dtype: int64

# %% [markdown]
# Its not much affect to the input columns and target column so futher we can drop it

# %%
df["Referred a Friend"].value_counts()
# Out:
# Referred a Friend
# No     1324
# Yes    1169
# Name: count, dtype: int64

# %% [markdown]
# Out of the total, only 1169 friends referred individuals to entities other than the company.

# %%
df["Number of Referrals"].value_counts()
# Out:
# Number of Referrals
# 0     1324
# 1      415
# 5       94
# 7       92
# 4       85
# 8       82
# 10      82
# 6       81
# 3       81
# 9       79
# 2       77
# 11       1
# Name: count, dtype: int64

# %% [markdown]
# The maximum number of referrals by a single friend is 11.

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=df["Streaming TV"],hue=df["Churn Label"])
plt.title("count of Customer streaming TV")
plt.xlabel("Streaming Tv")
plt.ylabel("Churn Label")
plt.show()

# %% [markdown]
# Since the number of Streaming of Tv shows minimal correlation with the target column and offers little impact on the analysis, it can be safely dropped from the dataset.

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=df["Streaming Music"],hue=df["Churn Label"])
plt.title("count of Customer streaming Music")
plt.xlabel("Streaming Music")
plt.ylabel("Churn Label")
plt.show()

# %% [markdown]
# Since the number of Streaming of Music shows minimal correlation with the target column and offers little impact on the analysis, it can be safely dropped from the dataset.

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=df["Streaming Movies"],hue=df["Churn Label"])
plt.title("count of Customer streaming Movies")
plt.xlabel("Streaming Movies")
plt.ylabel("Churn Label")
plt.show()

# %% [markdown]
# Since the number of Streaming Movies shows minimal correlation with the target column and offers little impact on the analysis, it can be safely dropped from the dataset.

# %%
df["Offer"].value_counts()
# Out:
# Offer
# Offer B    662
# Offer E    632
# Offer D    437
# Offer A    428
# Offer C    334
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df["Offer"],hue=df["Churn Label"])
plt.title("Offers for the Customer")
plt.xlabel("offer")
plt.ylabel("Churn Label")
plt.show()

# %% [markdown]
# Based on the analysis depicted in the chart, it can be inferred that customers are more inclined to leave the company when offered option E. Conversely, offering option B appears to increase the likelihood of customers staying with the company.

# %%
df["Phone Service"].value_counts()
# Out:
# Phone Service
# Yes    2194
# No      299
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=df["Phone Service"],hue=df["Churn Label"])
plt.title("Phone services the Customer")
plt.xlabel("Phone Services")
plt.ylabel("Churn Label")
plt.show()

# %% [markdown]
# It can be surmised that providing phone services to the company may correlate with a higher likelihood of customers choosing to remain with the company, potentially reducing the rate of attrition.

# %%
df.groupby("Churn Label")["Avg Monthly Long Distance Charges"].mean()
# Out:
# Churn Label
# No     22.520334
# Yes    22.826592
# Name: Avg Monthly Long Distance Charges, dtype: float64

# %% [markdown]
# Its same for both so it will not effect much to the column

# %%
df["Internet Service"].value_counts()
# Out:
# Internet Service
# Yes    2493
# Name: count, dtype: int64

# %%
df["Multiple Lines"].value_counts()
# Out:
# Multiple Lines
# No     1250
# Yes    1243
# Name: count, dtype: int64

# %%
df["Internet Type"].value_counts()
# Out:
# Internet Type
# Fiber Optic    1371
# DSL             743
# Cable           379
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=df["Internet Type"],hue=df["Churn Label"])
plt.title("Internet Type that Customer Consume")
plt.xlabel("Internet Services")
plt.ylabel("Churn Label")
plt.show()

# %% [markdown]
# Fiber Optic Consumption is more as compare ti DSL and Cable

# %%
df.groupby("Churn Label")["Avg Monthly GB Download"].sum()
# Out:
# Churn Label
# No     47860
# Yes    18800
# Name: Avg Monthly GB Download, dtype: int64

# %%
sns.violinplot(data=df,x= "Churn Label",y ="Avg Monthly GB Download")
plt.title("distribution of bills by gender")
plt.show()

# %%
sns.histplot(data=df,x="Avg Monthly GB Download",kde=True,hue="Churn Label")
plt.title("Avg Consumption of internet Month")

plt.show()

# %% [markdown]
# Based on the histogram presented, it appears that individuals who are associated with a company tend to consume more internet or download a higher average monthly gigabyte (GB) volume compared to those who are not affiliated with a company. This suggests that organizational affiliation might be a contributing factor to increased internet usage or data consumption habits.

# %%
df["Online Security"].value_counts()
# Out:
# Online Security
# No     1538
# Yes     955
# Name: count, dtype: int64

# %%
pd.crosstab(df["Churn Label"],df["Online Security"])
# Out:
# Online Security   No  Yes
# Churn Label
# No               913  823
# Yes              625  132

# %%
pd.crosstab(df["Churn Label"],df["Online Security"]).plot.pie(title = "Chrun label vs Online Security",subplots = True,legend = False,autopct = "%.2f%%")
# Out:
# array([<Axes: ylabel='No'>, <Axes: ylabel='Yes'>], dtype=object)

# %% [markdown]
# It seems that there is a discrepancy in the provided data regarding online security usage among customers who are associated with a company. Specifically, there are 913 customers who are not utilizing online security measures, while 823 customers who are taking advantage of online security services within the company.

# %%
df["Online Backup"].value_counts()
# Out:
# Online Backup
# No     1357
# Yes    1136
# Name: count, dtype: int64

# %%
pd.crosstab(df["Churn Label"],df["Online Backup"])
# Out:
# Online Backup   No  Yes
# Churn Label
# No             837  899
# Yes            520  237

# %%
pd.crosstab(df["Churn Label"],df["Online Backup"]).plot.pie(title = "Chrun label vs Online Backup",subplots = True,legend = False,autopct = "%.2f%%")
# Out:
# array([<Axes: ylabel='No'>, <Axes: ylabel='Yes'>], dtype=object)

# %% [markdown]
# The data indicates that 837 customers are not utilizing online backup services, while 899 customers who are affiliated with the company are utilizing these services.

# %%
df["Device Protection Plan"].value_counts()
# Out:
# Device Protection Plan
# No     1369
# Yes    1124
# Name: count, dtype: int64

# %%
pd.crosstab(df["Churn Label"],df["Device Protection Plan"])
# Out:
# Device Protection Plan   No  Yes
# Churn Label
# No                      854  882
# Yes                     515  242

# %%
pd.crosstab(df["Churn Label"],df["Device Protection Plan"]).plot.pie(title = "Chrun label vs Device Protection Plan",subplots = True,legend = False,autopct = "%.2f%%")
# Out:
# array([<Axes: ylabel='No'>, <Axes: ylabel='Yes'>], dtype=object)

# %% [markdown]
# It appears that among customers associated with the company, a substantial majority, accounting for 882 individuals or 78.47%, are opting for the device protection plan. In contrast, only a notably lower percentage, approximately 21.5%, of customers not affiliated with the company are choosing to enroll in the device protection plan. This data suggests a significant disparity in the adoption of device protection plans between customers who are and are not part of the company.

# %%
df["Premium Tech Support"].value_counts()
# Out:
# Premium Tech Support
# No     1566
# Yes     927
# Name: count, dtype: int64

# %%
pd.crosstab(df["Churn Label"],df["Premium Tech Support"])
# Out:
# Premium Tech Support   No  Yes
# Churn Label
# No                    945  791
# Yes                   621  136

# %% [markdown]
# Among customers affiliated with the company, approximately 62.38% are not opting for the premium service, while 78.47% are choosing to subscribe to the premium service. This suggests that there is a notable difference in the adoption of premium services among customers associated with the company.

# %%
df["Unlimited Data"].value_counts()
# Out:
# Unlimited Data
# Yes    2148
# No      345
# Name: count, dtype: int64

# %%
pd.crosstab(df["Churn Label"],df["Unlimited Data"])
# Out:
# Unlimited Data   No   Yes
# Churn Label
# No              234  1502
# Yes             111   646

# %%
pd.crosstab(df["Churn Label"],df["Unlimited Data"]).plot.pie(title = "Chrun label vs Unlimited Data",subplots = True,legend = False,autopct = "%.2f%%")
# Out:
# array([<Axes: ylabel='No'>, <Axes: ylabel='Yes'>], dtype=object)

# %% [markdown]
# The data indicates that the consumption of unlimited data is notably higher, with a total of 2148 units. Among these, 1502 units are consumed by customers associated with the company, while the remaining 646 units are consumed by customers not affiliated with the company. This suggests a significant disparity in unlimited data consumption between customers who are and are not part of the company.

# %%
df["Contract"].value_counts()
# Out:
# Contract
# Month-to-Month    1360
# Two Year           585
# One Year           548
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=df["Contract"],hue=df["Churn Label"])
plt.title("Contract of the Customer")
plt.xlabel("Contract")
plt.ylabel("Churn Label")
plt.show()

# %% [markdown]
# It appears that the month-to-month contract option is more popular compared to both the one-year and two-year contract options. However, interestingly, customers who opt for the two-year contract are less likely to leave the company compared to those on a month-to-month contract. This observation leads to the conclusion that customers may not be staying with the company after using the service for only a month, especially evident in the higher retention rate among customers with two-year contracts.

# %%
df["Paperless Billing"].value_counts()
# Out:
# Paperless Billing
# Yes    1689
# No      804
# Name: count, dtype: int64

# %% [markdown]
# It seems that the number of customers opting for paperless billing is twice that of those choosing paper billing. This trend indicates a strong preference among customers for digital transactions, as evidenced by the widespread use of online payment methods.

# %%
plt.figure(figsize=(6,5))
sns.countplot(x=df["Payment Method"],hue=df["Churn Label"])
plt.title("Billing Method")
plt.xlabel("Payment")
plt.ylabel("Churn Label")
plt.show()

# %%
pd.crosstab(df["Churn Label"],df["Payment Method"])
# Out:
# Payment Method  Bank Withdrawal  Credit Card  Mailed Check
# Churn Label
# No                          977          685            74
# Yes                         561          139            57

# %% [markdown]
# It appears that customers prefer to pay their bills through bank withdrawals over credit card transactions, with a preference for these methods over mailed checks. This trend suggests a higher level of convenience and efficiency associated with bank withdrawals and credit card payments compared to traditional mailed checks.

# %%
df.groupby("Churn Label")["Total Charges"].mean()
# Out:
# Churn Label
# No     3386.151354
# Yes    1602.460964
# Name: Total Charges, dtype: float64

# %%
df.groupby("Churn Label")["Total Refunds"].mean()
# Out:
# Churn Label
# No     1.783364
# Yes    1.845997
# Name: Total Refunds, dtype: float64

# %%
df.groupby("Churn Label")["Total Extra Data Charges"].mean()
# Out:
# Churn Label
# No     9.377880
# Yes    7.080581
# Name: Total Extra Data Charges, dtype: float64

# %%
df.groupby("Churn Label")["Monthly Charge"].mean()
# Out:
# Churn Label
# No     77.013105
# Yes    77.548018
# Name: Monthly Charge, dtype: float64

# %%
df.groupby("Churn Label")["Total Long Distance Charges"].mean()
# Out:
# Churn Label
# No     927.124384
# Yes    435.135178
# Name: Total Long Distance Charges, dtype: float64

# %% [markdown]
# #### Based on the analysis of the five charge credentials, it becomes evident that customers utilizing the services are incurring significantly higher charges, averaging at 3386 units. However, despite these substantial charges, the average refund amount remains relatively low, at just 1.7 units. Furthermore, there is a notable increase in both total extra data charges and total long-distance charges.
#
# #### This pattern strongly suggests that these charges might be a contributing factor to customers discontinuing their services shortly after subscribing, as observed previously. The high fees incurred alongside minimal refunds likely dissatisfy customers, potentially leading to their decision to discontinue the service.
# #####

# %%
df.groupby("Churn Label")["Total Revenue"].sum()
# Out:
# Churn Label
# No     7501030.76
# Yes    1546422.86
# Name: Total Revenue, dtype: float64

# %%
plt.figure(figsize=(2,2))
plt.pie(df.groupby("Churn Label")["Total Revenue"].sum(),   autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Total Revenue by Customer Type')
plt.axis('equal') 
plt.show()

# %% [markdown]
# #### 82.9% of revenue is coming from the customer who are taking the services
# #####

# %%
sns.barplot(data=df,x="Internet Type",y="Total Revenue")
plt.title("Total Revenue By Internet Type")
plt.show()

# %% [markdown]
# #### The bar plot analysis reveals that fiber optic services generate notably higher revenue compared to DSL and cable services. This observation suggests a strong preference among customers for fiber optic connections. The higher revenue generated by fiber optic services implies that customers are more inclined towards this particular service option, likely due to factors such as faster internet speeds, greater bandwidth, and enhanced connectivity experiences offered by fiber optic technology.
# #####

# %%
df["Satisfaction Score"].value_counts()
# Out:
# Satisfaction Score
# 3    989
# 4    608
# 1    362
# 5    313
# 2    221
# Name: count, dtype: int64

# %% [markdown]
# The data analysis indicates that satisfaction scores ranging from 1 to 3, representing levels of dissatisfaction, collectively amount to 1572. Conversely, satisfaction scores of 4 and 5, which signify higher satisfaction levels, have a combined total of 1021. Since scores of 4 and 5 are considered the best satisfaction levels, their lower cumulative count suggests a comparatively smaller portion of highly satisfied customers.
#
# This disparity in satisfaction levels directly influences the churn label, implying that a larger proportion of customers might be inclined towards discontinuing the service due to lower satisfaction levels. The imbalance in satisfaction scores underscores the importance of addressing customer concerns and enhancing service quality to mitigate churn risk and foster higher satisfaction levels.

# %%
df["Customer Status"].value_counts()
# Out:
# Customer Status
# Stayed     1620
# Churned     757
# Joined      116
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x="Customer Status",hue="Churn Label")
plt.show()

# %% [markdown]
# The analysis of the provided plot indicates several noteworthy observations regarding customer status within the company:
#
# 1. **Customer Retention**: Approximately 55% of customers are staying with the company, as evidenced by the "Stayed" category. This suggests a significant portion of the customer base remains loyal to the company's services.
#
# 2. **Churn Rate**: Around 45% of customers, represented by the "Churned" category, are leaving the company or discontinuing its services. This high churn rate indicates potential dissatisfaction or issues with the services provided, prompting customers to seek alternatives or discontinue their subscriptions.
#
# 3. **New Customer Acquisition**: The number of new customers, denoted by the "Joined" category, appears to be relatively low compared to the churned customers. This imbalance suggests challenges in attracting new customers to replace those who have churned, potentially indicating issues with customer acquisition strategies or market competitiveness.
#
# Overall, the analysis highlights the importance of addressing customer satisfaction and retention strategies to reduce churn rates and attract new customers effectively. Identifying and resolving the underlying issues contributing to customer churn is essential for fostering long-term customer loyalty and business sustainability.

# %%
df.groupby("Churn Label")["Churn Score"].mean()
# Out:
# Churn Label
# No     50.087558
# Yes    81.677675
# Name: Churn Score, dtype: float64

# %% [markdown]
# The higher the score, the more likely the customer will churn.

# %%
df.groupby("Churn Label")["CLTV"].mean()
# Out:
# Churn Label
# No     4567.391129
# Yes    4178.501982
# Name: CLTV, dtype: float64

# %% [markdown]
# The higher the value, the more valuable the customer. High value customers should be monitored for churn.

# %% [markdown]
# This summary provides a comprehensive overview of various insights gleaned from the visualization of the data:
#
# 1. **Customer Id**: Identified as a unique identifier, thus can be dropped.
# 2. **Gender**: Male customers are observed to leave the company or services more frequently than female customers.
# 3. **Age**: Customers above the age of 50 tend to discontinue internet services.
# 4. **Senior Citizen**: A significant minority of senior citizens opt to leave the company, while non-senior citizens display a higher propensity to stay.
# 5. **Married**: Marriage does not significantly influence the decision to retain or discontinue services.
# 6. **Dependents**: Customer independence does not significantly affect the target column, thus can be dropped.
# 7. **Location Details**: Address details are provided but may not be relevant to the target column; therefore, these columns can be dropped.
# 8. **Quarter**: Fiscal quarter Q3 does not provide substantial information.
# 9. **Referral Program**: Few customers utilize referral programs, indicating dissatisfaction with services.
# 10. **Streaming Services**: Customers actively engage with streaming services.
# 11. **Offer**: Offer B is more popular, while Offer E is less favored, indicating potential improvements needed for Offer E.
# 12. **Phone and Internet Services**: Customers heavily using phone services are observed to disconnect internet services more frequently.
# 13. **Internet Services**: Fiber optics are preferred by more customers and generate higher revenue.
# 14. **Data Consumption**: Internet consumption is higher among customers availing services.
# 15. **Contract**: Month-to-month contracts are prevalent, but customers tend to discontinue services shortly after.
# 16. **Payment Methods**: Online payment via automatic bank withdrawal is the preferred mode.
# 17. **Charges and Refunds**: Charges are high, while refunds are low, potentially driving customer dissatisfaction and service discontinuation.
# 18. **Satisfaction Score**: Overall satisfaction scores indicate dissatisfaction among customers.
# 19. **Customer Status**: A significant portion of customers churn, while new joiners are minimal, especially those with longer contract durations.
#
# These insights highlight areas where the company may need to focus on improving customer satisfaction, retention strategies, and service quality to reduce churn rates and attract new customers effectively.

# %%
drop_col = ["Customer ID","Country","State","City","Zip Code","Latitude","Longitude","Quarter","Paperless Billing","Dependents","Number of Dependents"]

# %%
df.drop(columns = drop_col,inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def encoder(df):
    encoder = LabelEncoder()
    for column in df.columns:
      if df[column].dtype=="object":
          df[column] = encoder.fit_transform(df[column])
    print("Encoding Process Completed")
encoder(df)
# Out:
# Encoding Process Completed

# %% [markdown]
# Successfully dropping columns that are not correlated with the target column and performing label encoding are crucial steps in data preprocessing to prepare the dataset for further analysis or modeling

# %%
df["Churn Label"].value_counts()
# Out:
# Churn Label
# 0    1736
# 1     757
# Name: count, dtype: int64

# %% [markdown]
# "In this scenario, data resampling is required due to a significant imbalance in the output column categories. Resampling is the process of adjusting the data distribution to mitigate this discrepancy and ensure a more equitable representation of each category."

# %%
from sklearn.utils import resample

# %%
target_col = df[df["Churn Label"]==0]
target = df[df["Churn Label"]==1]

# %%
sampling = resample(target,n_samples = len(target_col))

# %%
df = pd.concat([target_col,sampling],axis =0)

# %%
df["Churn Label"].value_counts()
# Out:
# Churn Label
# 0    1736
# 1    1736
# Name: count, dtype: int64

# %% [markdown]
# we have  successfully resample the data

# %%
plt.figure(figsize = (30,30))
sns.heatmap(df.corr(),annot = True,fmt= ".2f",vmax = 1 ,vmin = -1)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                                      Gender       Age  Under 30  \
# Gender                             1.000000 -0.004079 -0.009681
# Age                               -0.004079  1.000000 -0.669797
# Under 30                          -0.009681 -0.669797  1.000000
# Senior Citizen                    -0.004564  0.706426 -0.238894
# Married                            0.030093 -0.020169  0.016935
# Population                        -0.032413 -0.027563  0.059927
# Referred a Friend                  0.029114 -0.021221  0.013865
# Number of Referrals                0.017031 -0.035546  0.013969
# Tenure in Months                   0.038000 -0.033643  0.034713
# Offer                             -0.041005  0.023723 -0.031398
# Phone Service                     -0.032244  0.018427 -0.004751
# Avg Monthly Long Distance Charges  0.003817  0.008632 -0.013141
# Multiple Lines                     0.013695  0.042433  0.012579
# Internet Service                        NaN       NaN       NaN
# ...

# %% [markdown]
# #### "The heatmap analysis reveals notable correlations between the churn label and several key variables, including churn score, customer status, satisfaction score, contract type, offer, and tenure in months. These variables demonstrate stronger associations with the churn label, indicating their potential significance in predicting churn behavior."
# #####

# %%
df.reset_index(drop = True,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3472 entries, 0 to 3471
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             3472 non-null   int32
#  1   Age                                3472 non-null   int64
#  2   Under 30                           3472 non-null   int32
#  3   Senior Citizen                     3472 non-null   int32
#  4   Married                            3472 non-null   int32
#  5   Population                         3472 non-null   int64
#  6   Referred a Friend                  3472 non-null   int32
#  7   Number of Referrals                3472 non-null   int64
#  8   Tenure in Months                   3472 non-null   int64
#  9   Offer                              3472 non-null   int32
#  10  Phone Service                      3472 non-null   int32
# ...

# %% [markdown]
# Here we are creating a list of all the columns

# %%
nums_col =  [ i for i in df.columns if df[i].dtype !="O"]

# %%
nums_col
# Out:
# ['Gender',
#  'Age',
#  'Under 30',
#  'Senior Citizen',
#  'Married',
#  'Population',
#  'Referred a Friend',
#  'Number of Referrals',
#  'Tenure in Months',
#  'Offer',
#  'Phone Service',
#  'Avg Monthly Long Distance Charges',
#  'Multiple Lines',
#  'Internet Service',
#  'Internet Type',
#  'Avg Monthly GB Download',
#  'Online Security',
#  'Online Backup',
#  'Device Protection Plan',
#  'Premium Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Streaming Music',
#  'Unlimited Data',
#  'Contract',
#  'Payment Method',
#  'Monthly Charge',
#  'Total Charges',
#  'Total Refunds',
#  'Total Extra Data Charges',
#  'Total Long Distance Charges',
#  'Total Revenue',
#  'Satisfaction Score',
#  'Customer Status',
#  'Churn Label',
#  'Churn Score',
#  'CLTV']

# %% [markdown]
# "We have generated box plots for all columns, revealing the presence of outliers across the dataset. Addressing these outliers is essential to ensure the integrity and reliability of our analysis, necessitating further investigation and potential remedial measures."

# %%
for i in nums_col:
    plt.figure(figsize=(10,4))
    plt.boxplot(df[i],vert = False)
    plt.xlabel(i)
    plt.title("Distribution of {}".format(i))
    plt.show()

# %%
df["Population"].describe()
# Out:
# count      3472.000000
# mean      22391.790611
# std       21201.533045
# min          11.000000
# 25%        2345.500000
# 50%       17944.000000
# 75%       36723.000000
# max      105285.000000
# Name: Population, dtype: float64

# %%
df["Population"].quantile(0.995)
# Out:
# 91664.0

# %%
df = df[df["Population"]<90891]

# %% [markdown]
# After applying the 0.995 quantile to the population, the resulting value was 90891. Out of the initial 3471 rows, 3449 rows remained post-quantile application."

# %%
df["Number of Referrals"].describe()
# Out:
# count    3451.000000
# mean        1.582730
# std         2.707645
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        11.000000
# Name: Number of Referrals, dtype: float64

# %%
df["Number of Referrals"].quantile(0.95)
# Out:
# 8.0

# %% [markdown]
# We have decided against applying the quantile here due to the significant reduction in the number of rows that would result from its implementation.

# %%
df["Avg Monthly GB Download"].describe()
# Out:
# count    3451.000000
# mean       26.039699
# std        19.530723
# min         2.000000
# 25%        12.000000
# 50%        21.000000
# 75%        30.000000
# max        85.000000
# Name: Avg Monthly GB Download, dtype: float64

# %%
df["Avg Monthly GB Download"].quantile(0.95)
# Out:
# 71.0

# %%
df = df[df["Avg Monthly GB Download"]<71]

# %% [markdown]
# The quantile analysis on the average monthly gigabyte download yields a result of 71. Among 3449 rows, 3275 fall below this threshold.

# %%
df["Total Refunds"].describe()
# Out:
# count    3269.000000
# mean        2.028633
# std         8.202384
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        49.510000
# Name: Total Refunds, dtype: float64

# %%
df["Total Refunds"].quantile(0.935)
# Out:
# 4.93

# %%
df = df[df["Total Refunds"]<2.3]

# %% [markdown]
# We applied a quantile analysis to the Total refunds data, yielding a result of 2.3.

# %%
df["Total Extra Data Charges"].describe()
# Out:
# count    3041.000000
# mean        8.625452
# std        27.574387
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       150.000000
# Name: Total Extra Data Charges, dtype: float64

# %%
df["Total Extra Data Charges"].quantile(0.9)
# Out:
# 20.0

# %%
df  = df[df["Total Extra Data Charges"]<20]

# %%
#2744

# %%
df["Total Long Distance Charges"].describe()
# Out:
# count    2715.000000
# mean      629.091853
# std       814.098048
# min         0.000000
# 25%        36.005000
# 50%       246.560000
# 75%       910.860000
# max      3515.920000
# Name: Total Long Distance Charges, dtype: float64

# %%
df["Total Long Distance Charges"].quantile(0.95)
# Out:
# 2519.821

# %%
df = df[df["Total Long Distance Charges"]<2079]

# %%
df["Total Charges"].describe()
# Out:
# count    2486.000000
# mean     2007.180732
# std      2149.426160
# min        23.450000
# 25%       217.062500
# 50%      1154.525000
# 75%      3208.862500
# max      8594.400000
# Name: Total Charges, dtype: float64

# %%
df["Total Charges"].quantile(0.99)
# Out:
# 7885.762500000002

# %%
df = df[df["Total Charges"]<7968]

# %% [markdown]
# Similarly for extra charges and total extra charges

# %%
df.reset_index(drop = True,inplace = True)

# %% [markdown]
# After applying quantiles, resetting the index is necessary to rectify the indexing numbers.

# %%
for i in nums_col:
    plt.figure(figsize=(10,4))
    plt.boxplot(df[i],vert = False)
    plt.xlabel(i)
    plt.title("Distribution of {}".format(i))
    plt.show()

# %% [markdown]
# Cross-verification is required to determine if outliers persist after analysis. While complete outlier removal can lead to a loss of 75% of the data, retaining some outliers might be desirable.

# %%
num = nums_col[:-3] + nums_col[-2:]
num
# Out:
# ['Gender',
#  'Age',
#  'Under 30',
#  'Senior Citizen',
#  'Married',
#  'Population',
#  'Referred a Friend',
#  'Number of Referrals',
#  'Tenure in Months',
#  'Offer',
#  'Phone Service',
#  'Avg Monthly Long Distance Charges',
#  'Multiple Lines',
#  'Internet Service',
#  'Internet Type',
#  'Avg Monthly GB Download',
#  'Online Security',
#  'Online Backup',
#  'Device Protection Plan',
#  'Premium Tech Support',
#  'Streaming TV',
#  'Streaming Movies',
#  'Streaming Music',
#  'Unlimited Data',
#  'Contract',
#  'Payment Method',
#  'Monthly Charge',
#  'Total Charges',
#  'Total Refunds',
#  'Total Extra Data Charges',
#  'Total Long Distance Charges',
#  'Total Revenue',
#  'Satisfaction Score',
#  'Customer Status',
#  'Churn Score',
#  'CLTV']

# %% [markdown]
# We've generated a list devoid of the target column.

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()

# %%
X= df.drop("Churn Label",axis = 1)
y = df["Churn Label"]

# %% [markdown]
# Here, we imported the StandardScaler to transform the data into standard values, ensuring uniformity in scale across features. Additionally, the train_test_split function was utilized to partition the data into separate sets for training and testing, facilitating model evaluation and validation.

# %%
X_tr,X_te,y_tr,y_te = train_test_split(X,y,train_size=0.75,random_state = 234)

# %%
scaled_train = scaler.fit_transform(X_tr[num])

# %%
scaled_test = scaler.fit_transform(X_te[num])

# %%
X_tr[num] = scaled_train

# %%
X_te[num] = scaled_test

# %% [markdown]
# We have successfully split the data and applied the scaler to both fit and transform the dataset, ensuring consistency in feature scaling for subsequent analysis.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 15)

# %%
X_tr= pca.fit_transform(X_tr)

# %%
X_te  = pca.transform(X_te)

# %% [markdown]
# Applying Principal Component Analysis (PCA) is beneficial for dimensionality reduction and feature extraction. It helps in reducing the number of features while retaining most of the variance in the data, thus simplifying the computational complexity and potentially improving model performance by removing noise and redundancy in the dataset.

# %%
X_tr.shape
# Out:
# (1847, 15)

# %%
X_te.shape
# Out:
# (616, 15)

# %%
from sklearn.model_selection import GridSearchCV,KFold,cross_val_score
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,recall_score,f1_score,precision_score

# %%
log = LogisticRegression()
dt = DecisionTreeClassifier()
knn = KNeighborsClassifier(n_neighbors = 11)
lsvc = SVC(kernel = "linear")
psvc = SVC(kernel = "poly")
rsvc = SVC(kernel = "rbf")
rf = RandomForestClassifier(n_estimators = 150,n_jobs = -1)
ab = AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=150)

# %%
log.fit(X_tr,y_tr)
dt.fit(X_tr,y_tr)
knn.fit(X_tr,y_tr)
lsvc.fit(X_tr,y_tr)
psvc.fit(X_tr,y_tr)
rsvc.fit(X_tr,y_tr)
rf.fit(X_tr,y_tr)
ab.fit(X_tr,y_tr)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=150)

# %%
print("Logistic Score:",log.score(X_tr,y_tr))
print("Decsison Tree Score:",dt.score(X_tr,y_tr))
print("KNN Score:",knn.score(X_tr,y_tr))
print("Linera SVC Score:",lsvc.score(X_tr,y_tr))
print("poly svc Score:",psvc.score(X_tr,y_tr))
print("rbf svc Score:",rsvc.score(X_tr,y_tr))
print("Random Forest Score:",rf.score(X_tr,y_tr))
print("Adaboost Score:",ab.score(X_tr,y_tr))
# Out:
# Logistic Score: 0.9972929074174337
# Decsison Tree Score: 1.0
# KNN Score: 0.9794260963724959
# Linera SVC Score: 0.9983757444504602
# poly svc Score: 0.9962100703844071
# rbf svc Score: 0.9962100703844071
# Random Forest Score: 1.0
# Adaboost Score: 1.0

# %%
print("Logistic Accuracy:",accuracy_score(y_te,log.predict(X_te)))
print("Decision Tree Accuracy:",accuracy_score(y_te,dt.predict(X_te)))
print("KNN Accuracy:",accuracy_score(y_te,knn.predict(X_te)))
print("LINEAR SVC Accuracy:",accuracy_score(y_te,lsvc.predict(X_te)))
print("POLY SVC Accuracy:",accuracy_score(y_te,psvc.predict(X_te)))
print("RBF SVC Accuracy:",accuracy_score(y_te,rsvc.predict(X_te)))
print("random forest Accuracy:",accuracy_score(y_te,rf.predict(X_te)))
print("Adaboost Accuracy:",accuracy_score(y_te,ab.predict(X_te)))
# Out:
# Logistic Accuracy: 0.9967532467532467
# Decision Tree Accuracy: 0.9545454545454546
# KNN Accuracy: 0.9675324675324676
# LINEAR SVC Accuracy: 0.9951298701298701
# POLY SVC Accuracy: 0.9951298701298701
# RBF SVC Accuracy: 0.9967532467532467
# random forest Accuracy: 0.9886363636363636
# Adaboost Accuracy: 0.9561688311688312

# %%
def evaluate_model(model,X_tr,X_te,y_tr,y_te):
    model.fit(X_tr,y_tr)
    score=model.score(X_tr,y_tr)
    print("score",score)
    
    y_pr_tr=model.predict(X_tr)
    y_pr_te=model.predict(X_te)
    accuracy=accuracy_score(y_te,y_pr_te)
    print("accuracy",accuracy)
    
    pred_prob_train = model.predict_proba(X_tr)[:,1]
    pred_prob_test = model.predict_proba(X_te)[:,1]
    
    roc_score_train=roc_auc_score(y_tr,y_pr_tr)
    roc_score_test=roc_auc_score(y_te,y_pr_te)
    print("roc_train_score",roc_score_train)
    print("roc_test_score",roc_score_test)
    
    fpr,tpr,threshold=roc_curve(y_te,pred_prob_test)
    roc_auc = auc(fpr, tpr)
    
    plt.figure()
    plt.plot(fpr, tpr, color="red", label="ROC Curve (Area=%0.2f)"%roc_auc)
    plt.plot([0, 1], [0, 1], color="navy", linestyle="--")
    plt.xlim([-0.05, 1.0vhb j    
    plt.ylim([0.0, 1.05])
    plt.xlabel("FPR")
    plt.ylabel("TPR")
    plt.title("ROC-AUC Curve")
    plt.legend()
    plt.show()
    
    print("classification_report",classification_report(y_te, y_pr_te))
    print("confusion_matrix",confusion_matrix(y_te,y_pr_te))

# %% [markdown]
# # Logistic Regression Model

# %%
lr_model = LogisticRegression()

# %%
lr_score = evaluate_model(lr_model,X_tr,X_te,y_tr,y_te)
# Out:
# score 0.9972929074174337
# accuracy 0.9967532467532467
# roc_train_score 0.9972008372569867
# roc_test_score 0.9965635738831615
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       291
#            1       0.99      1.00      1.00       325
#
#     accuracy                           1.00       616
#    macro avg       1.00      1.00      1.00       616
# weighted avg       1.00      1.00      1.00       616
#
# confusion_matrix [[289   2]
#  [  0 325]]

# %% [markdown]
#  # Decision Tree Model

# %%
de_model  = DecisionTreeClassifier()

# %%
de_score = evaluate_model(de_model ,X_tr,X_te,y_tr,y_te)
# Out:
# score 1.0
# accuracy 0.9577922077922078
# roc_train_score 1.0
# roc_test_score 0.9562252180808882
# classification_report               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95       291
#            1       0.94      0.98      0.96       325
#
#     accuracy                           0.96       616
#    macro avg       0.96      0.96      0.96       616
# weighted avg       0.96      0.96      0.96       616
#
# confusion_matrix [[270  21]
#  [  5 320]]

# %% [markdown]
# # KNN MODEL

# %%
knn_model = KNeighborsClassifier(n_neighbors = 11)

# %%
knn_score = evaluate_model(knn_model ,X_tr,X_te,y_tr,y_te)
# Out:
# score 0.9794260963724959
# accuracy 0.9675324675324676
# roc_train_score 0.9778677475698664
# roc_test_score 0.9667142479513614
# classification_report               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       291
#            1       0.96      0.98      0.97       325
#
#     accuracy                           0.97       616
#    macro avg       0.97      0.97      0.97       616
# weighted avg       0.97      0.97      0.97       616
#
# confusion_matrix [[277  14]
#  [  6 319]]

# %% [markdown]
# # Random Forest Classifier

# %%
rf_model = RandomForestClassifier(n_estimators = 150,n_jobs = -1)

# %%
rf_score = evaluate_model(rf_model ,X_tr,X_te,y_tr,y_te)
# Out:
# score 1.0
# accuracy 0.9902597402597403
# roc_train_score 1.0
# roc_test_score 0.9898704731694422
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       291
#            1       0.98      1.00      0.99       325
#
#     accuracy                           0.99       616
#    macro avg       0.99      0.99      0.99       616
# weighted avg       0.99      0.99      0.99       616
#
# confusion_matrix [[286   5]
#  [  1 324]]

# %% [markdown]
# # Ada boost Technique

# %%
ab_model = AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=150)

# %%
ab_score = evaluate_model(ab_model ,X_tr,X_te,y_tr,y_te)
# Out:
# score 1.0
# accuracy 0.9496753246753247
# roc_train_score 1.0
# roc_test_score 0.9481734073486652
# classification_report               precision    recall  f1-score   support
#
#            0       0.97      0.92      0.95       291
#            1       0.93      0.98      0.95       325
#
#     accuracy                           0.95       616
#    macro avg       0.95      0.95      0.95       616
# weighted avg       0.95      0.95      0.95       616
#
# confusion_matrix [[268  23]
#  [  8 317]]

# %% [markdown]
# # SVC Model

# %%
svc = SVC(kernel = "linear",probability=True)

# %%
svc_score = evaluate_model(svc,X_tr,X_te,y_tr,y_te)
# Out:
# score 0.9983757444504602
# accuracy 0.9951298701298701
# roc_train_score 0.9981773997569867
# roc_test_score 0.9948453608247423
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       291
#            1       0.99      1.00      1.00       325
#
#     accuracy                           1.00       616
#    macro avg       1.00      0.99      1.00       616
# weighted avg       1.00      1.00      1.00       616
#
# confusion_matrix [[288   3]
#  [  0 325]]

# %%
svc_poly = SVC(kernel = "poly",probability=True)

# %%
svc_score1 = evaluate_model(svc_poly,X_tr,X_te,y_tr,y_te)
# Out:
# score 0.9962100703844071
# accuracy 0.9951298701298701
# roc_train_score 0.995985770428311
# roc_test_score 0.9948453608247423
# classification_report               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       291
#            1       0.99      1.00      1.00       325
#
#     accuracy                           1.00       616
#    macro avg       1.00      0.99      1.00       616
# weighted avg       1.00      1.00      1.00       616
#
# confusion_matrix [[288   3]
#  [  0 325]]

# %%
svc_rbf = SVC(kernel = "rbf",probability=True)

# %%
svc_score2 = evaluate_model(svc_rbf,X_tr,X_te,y_tr,y_te)
# Out:
# score 0.9962100703844071
# accuracy 0.9967532467532467
# roc_train_score 0.9961050225926488
# roc_test_score 0.9969230769230769
# classification_report               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       291
#            1       1.00      0.99      1.00       325
#
#     accuracy                           1.00       616
#    macro avg       1.00      1.00      1.00       616
# weighted avg       1.00      1.00      1.00       616
#
# confusion_matrix [[291   0]
#  [  2 323]]

# %% [markdown]
# #### Certainly! When selecting the Random Forest classifier due to its superior performance, we can further optimize its hyperparameters using GridSearchCV. GridSearchCV is a method in scikit-learn that exhaustively searches over a specified parameter grid to find the best combination of hyperparameters for a given estimator.
#
#
# #### Here's how you can perform GridSearchCV with Random Forest Classifier:
# #####

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10], 
    'min_samples_leaf': [1, 2, 4] 
}
rf = RandomForestClassifier()
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_tr, y_tr)
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best Score: 1.0

# %% [markdown]
# # Summary

# %% [markdown]
# ### In our telecom project, we began by visualizing the dataset, which focuses on internet services provided by the company. Our target variable, "churn Label" indicates whether a customer has left the company (1) or remains with the services (0). After thorough data cleaning, we removed irrelevant columns and encoded categorical variables. Resampling techniques were applied to address class imbalance, followed by standardization for uniformity in feature scaling.
#
# ### A crucial step involved creating a function for data splitting and model evaluation. This function allows for streamlined testing of various models by inputting the model and data, yielding accuracy scores, predicted values, AUC values, ROC curves, and classification reports.
#
# ### Our analysis revealed that the Random Forest model fits the data best, particularly due to its higher precision. Precision, emphasizing accurate positive predictions, aids in targeted interventions and retention strategies for at-risk customers. However, it's essential to balance precision with recall, ensuring the model effectively identifies churn cases without overlooking potential opportunities.
#
# ### In conclusion, our project demonstrates a comprehensive approach to churn prediction in the telecom sector, leveraging data visualization, cleaning, encoding, resampling, and model evaluation techniques. By prioritizing precision and selecting the Random Forest model.
# #####
